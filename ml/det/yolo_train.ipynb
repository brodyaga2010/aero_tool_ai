# %%
import torch
def cosine_scheduler(optimizer, epochs, warmup=3):
    """cosine annealing lr scheduler"""
    return torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=epochs - warmup,
        eta_min=1e-6
    )

# %%
import torch
import torch.nn as nn

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0, reduction="mean"):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        self.bce = nn.BCEWithLogitsLoss(reduction="none")

    def forward(self, preds, targets):
        bce_loss = self.bce(preds, targets)
        pt = torch.exp(-bce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * bce_loss
        if self.reduction == "mean":
            return focal_loss.mean()
        elif self.reduction == "sum":
            return focal_loss.sum()
        else:
            return focal_loss

# %%
import os
import numpy as np
import yaml
import torch
from ultralytics import YOLO

# --------------------------
# Функция подсчета объектов по классам
# --------------------------
def count_classes(data_yaml: str):
    with open(data_yaml, "r") as f:
        data = yaml.safe_load(f)

    names = data["names"]
    num_classes = len(names)

    root = data["path"]
    label_dirs = [
        os.path.join(root, "labels", "train"),
        os.path.join(root, "labels", "val")
    ]

    counts = np.zeros(num_classes, dtype=np.int64)

    for label_dir in label_dirs:
        if not os.path.exists(label_dir):
            continue
        for file in os.listdir(label_dir):
            if file.endswith(".txt"):
                path = os.path.join(label_dir, file)
                with open(path, "r") as f:
                    for line in f:
                        if line.strip() == "":
                            continue
                        cls_id = int(line.split()[0])
                        counts[cls_id] += 1

    return names, counts

# --------------------------
# Загружаем датасет и считаем alpha
# --------------------------
data_yaml = "dataset.yaml" 
names, counts = count_classes(data_yaml)
print("Классы:", names)
print("Количество объектов по классам:", counts.tolist())

# Построим alpha вектор для FocalLoss
inv = 1.0 / (counts + 1e-6)
alpha = inv / inv.sum()
alpha = torch.tensor(alpha, dtype=torch.float32)
print("Alpha вектор:", alpha.tolist())

# --------------------------
# Инициализация модели
# --------------------------
model = YOLO("yolov8n.pt")

# --------------------------
# Кастомный FocalLoss
# --------------------------
focal_loss = FocalLoss(alpha=alpha, gamma=2.0)

def custom_loss(preds, targets):
    # стандартный лосс для bbox/obj/dfl
    loss_items = model.trainer.criterion(preds, targets)

    # классификация
    cls_preds = preds[0].cls
    targets_dict = model.trainer.build_targets(preds, targets)[0]
    cls_targets = targets_dict["cls"].to(cls_preds.device)

    focal_cls_loss = focal_loss(cls_preds, cls_targets)

    # финальный лосс
    total_loss = (
        loss_items["box"] +
        loss_items["obj"] +
        loss_items.get("dfl", 0) +
        focal_cls_loss
    )
    return total_loss

# --------------------------
# Callback для подмены loss
# --------------------------
def on_train_start(trainer):
    trainer.loss = custom_loss

model.add_callback("on_train_start", on_train_start)
# Out:
# Классы: {0: 'Adjustable_wrench', 1: 'screwdriver_1', 2: 'screwdriver_2', 3: 'Offset_Phillips_screwdriver', 4: 'Side_cutters', 5: 'Shernica', 6: 'Safety_pliers', 7: 'Pliers', 8: 'Rotary_wheel', 9: 'Open_end_wrench', 10: 'Oil_can_opener'}
# Количество объектов по классам: [715, 240, 396, 349, 335, 735, 944, 407, 836, 449, 297]
# Alpha вектор: [0.05461550131440163, 0.16270866990089417, 0.09861131757497787, 0.11189135164022446, 0.11656741052865982, 0.05312936380505562, 0.041366614401340485, 0.09594614803791046, 0.046710625290870667, 0.0869712308049202, 0.13148175179958344]
# Transferred 319/355 items from pretrained weights

# %%
# --------------------------
# Тренировка
# --------------------------

results = model.train(
    data=data_yaml,
    epochs=200,
    imgsz=640,
    device="cuda",
    batch=20,
    optimizer="AdamW",
    lr0=0.00044372638023533847,
    weight_decay=0.0015776452546715513,
    momentum=0.8792977803712093,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.204 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203  Python-3.12.6 torch-2.10.0.dev20250926+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=20, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.00044372638023533847, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.8792977803712093, mosaic=1.0, multi_scale=False, name=train26, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=S:/hacatons/tools/Tools_yolov8-8/runs/detect/train25/weights/best.pt, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=S:\hacatons\tools\Tools_yolov8-8\runs\detect\train26, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0015776452546715513, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753457  ultralytics.nn.modules.head.Detect           [11, [64, 128, 256]]
# Model summary: 129 layers, 3,012,993 parameters, 3,012,977 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 162.766.3 MB/s, size: 127.7 KB)
# train: Scanning S:\hacatons\tools\Tools_yolov8-8\data\labels\train.cache... 4734 images, 1 backgrounds, 374 corrupt: 100% ━━━━━━━━━━━━ 4734/4734 6.0Mit/s 0.0s
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0001.jpg: ignoring corrupt image/label: could not convert string to float: '0.070801/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0002.jpg: ignoring corrupt image/label: could not convert string to float: '0.260260/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0003.jpg: ignoring corrupt image/label: could not convert string to float: '0.027483/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0004.jpg: ignoring corrupt image/label: could not convert string to float: '0.170898/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0005.jpg: ignoring corrupt image/label: could not convert string to float: '0.174764/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0006.jpg: ignoring corrupt image/label: could not convert string to float: '0.206442/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0007.jpg: ignoring corrupt image/label: could not convert string to float: '0.053074/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0008.jpg: ignoring corrupt image/label: could not convert string to float: '0.028809/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0009.jpg: ignoring corrupt image/label: could not convert string to float: '0.245074/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0010.jpg: ignoring corrupt image/label: could not convert string to float: '0.369508/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0011.jpg: ignoring corrupt image/label: could not convert string to float: '0.390082/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0012.jpg: ignoring corrupt image/label: could not convert string to float: '0.157715/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0013.jpg: ignoring corrupt image/label: could not convert string to float: '0.042969/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0014.jpg: ignoring corrupt image/label: could not convert string to float: '0.049391/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0015.jpg: ignoring corrupt image/label: could not convert string to float: '0.074382/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0016.jpg: ignoring corrupt image/label: could not convert string to float: '0.430370/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0017.jpg: ignoring corrupt image/label: could not convert string to float: '0.331536/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0018.jpg: ignoring corrupt image/label: could not convert string to float: '0.353516/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0019.jpg: ignoring corrupt image/label: could not convert string to float: '0.566300/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0020.jpg: ignoring corrupt image/label: could not convert string to float: '0.201408/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0021.jpg: ignoring corrupt image/label: could not convert string to float: '0.164062/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0022.jpg: ignoring corrupt image/label: could not convert string to float: '0.160317/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0023.jpg: ignoring corrupt image/label: could not convert string to float: '0.077148/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0024.jpg: ignoring corrupt image/label: could not convert string to float: '0.068242/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0025.jpg: ignoring corrupt image/label: could not convert string to float: '0.219514/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0026.jpg: ignoring corrupt image/label: could not convert string to float: '0.208494/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0027.jpg: ignoring corrupt image/label: could not convert string to float: '0.041016/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0028.jpg: ignoring corrupt image/label: could not convert string to float: '0.119269/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0029.jpg: ignoring corrupt image/label: could not convert string to float: '0.173173/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0030.jpg: ignoring corrupt image/label: could not convert string to float: '0.318359/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0031.jpg: ignoring corrupt image/label: could not convert string to float: '0.251783/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0032.jpg: ignoring corrupt image/label: could not convert string to float: '0.286304/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0033.jpg: ignoring corrupt image/label: could not convert string to float: '0.194909/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0034.jpg: ignoring corrupt image/label: could not convert string to float: '0.503621/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0035.jpg: ignoring corrupt image/label: could not convert string to float: '0.083496/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0036.jpg: ignoring corrupt image/label: could not convert string to float: '0.485242/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0037.jpg: ignoring corrupt image/label: could not convert string to float: '0.175337/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0038.jpg: ignoring corrupt image/label: could not convert string to float: '0.123103/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0039.jpg: ignoring corrupt image/label: could not convert string to float: '0.231934/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0040.jpg: ignoring corrupt image/label: could not convert string to float: '0.116576/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0041.jpg: ignoring corrupt image/label: could not convert string to float: '0.102216/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0042.jpg: ignoring corrupt image/label: could not convert string to float: '0.084473/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0043.jpg: ignoring corrupt image/label: could not convert string to float: '0.205566/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0044.jpg: ignoring corrupt image/label: could not convert string to float: '0.287518/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0045.jpg: ignoring corrupt image/label: could not convert string to float: '0.284745/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0046.jpg: ignoring corrupt image/label: could not convert string to float: '0.188477/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0047.jpg: ignoring corrupt image/label: could not convert string to float: '0.065382/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0048.jpg: ignoring corrupt image/label: could not convert string to float: '0.191086/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0049.jpg: ignoring corrupt image/label: could not convert string to float: '0.211866/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0050.jpg: ignoring corrupt image/label: could not convert string to float: '0.124845/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0051.jpg: ignoring corrupt image/label: could not convert string to float: '0.217285/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0052.jpg: ignoring corrupt image/label: could not convert string to float: '0.136549/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0053.jpg: ignoring corrupt image/label: could not convert string to float: '0.139648/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0054.jpg: ignoring corrupt image/label: could not convert string to float: '0.103962/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0055.jpg: ignoring corrupt image/label: could not convert string to float: '0.183322/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0056.jpg: ignoring corrupt image/label: could not convert string to float: '0.297762/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0057.jpg: ignoring corrupt image/label: could not convert string to float: '0.167969/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0058.jpg: ignoring corrupt image/label: could not convert string to float: '0.276580/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0059.jpg: ignoring corrupt image/label: could not convert string to float: '0.280781/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0060.jpg: ignoring corrupt image/label: could not convert string to float: '0.261230/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0061.jpg: ignoring corrupt image/label: could not convert string to float: '0.253906/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0062.jpg: ignoring corrupt image/label: could not convert string to float: '0.261392/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0063.jpg: ignoring corrupt image/label: could not convert string to float: '0.329066/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0064.jpg: ignoring corrupt image/label: could not convert string to float: '0.094383/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0065.jpg: ignoring corrupt image/label: could not convert string to float: '0.100706/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0066.jpg: ignoring corrupt image/label: could not convert string to float: '0.274902/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0067.jpg: ignoring corrupt image/label: could not convert string to float: '0.155968/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0068.jpg: ignoring corrupt image/label: could not convert string to float: '0.227539/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0069.jpg: ignoring corrupt image/label: could not convert string to float: '0.284842/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0070.jpg: ignoring corrupt image/label: could not convert string to float: '0.150436/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0071.jpg: ignoring corrupt image/label: could not convert string to float: '0.114017/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0072.jpg: ignoring corrupt image/label: could not convert string to float: '0.386719/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0073.jpg: ignoring corrupt image/label: could not convert string to float: '0.187132/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0074.jpg: ignoring corrupt image/label: could not convert string to float: '0.309082/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0075.jpg: ignoring corrupt image/label: could not convert string to float: '0.169048/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0076.jpg: ignoring corrupt image/label: could not convert string to float: '0.206979/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0077.jpg: ignoring corrupt image/label: could not convert string to float: '0.194824/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0078.jpg: ignoring corrupt image/label: could not convert string to float: '0.195571/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0079.jpg: ignoring corrupt image/label: could not convert string to float: '0.132812/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0080.jpg: ignoring corrupt image/label: could not convert string to float: '0.329946/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0081.jpg: ignoring corrupt image/label: could not convert string to float: '0.350756/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0082.jpg: ignoring corrupt image/label: could not convert string to float: '0.439998/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0083.jpg: ignoring corrupt image/label: could not convert string to float: '0.632663/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0084.jpg: ignoring corrupt image/label: could not convert string to float: '0.565430/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0085.jpg: ignoring corrupt image/label: could not convert string to float: '0.172075/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0086.jpg: ignoring corrupt image/label: could not convert string to float: '0.215820/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0087.jpg: ignoring corrupt image/label: could not convert string to float: '0.185318/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0088.jpg: ignoring corrupt image/label: could not convert string to float: '0.253418/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0089.jpg: ignoring corrupt image/label: could not convert string to float: '0.507606/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0090.jpg: ignoring corrupt image/label: could not convert string to float: '0.285944/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0091.jpg: ignoring corrupt image/label: could not convert string to float: '0.084882/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0092.jpg: ignoring corrupt image/label: could not convert string to float: '0.166504/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0093.jpg: ignoring corrupt image/label: could not convert string to float: '0.174215/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0094.jpg: ignoring corrupt image/label: could not convert string to float: '0.272147/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0095.jpg: ignoring corrupt image/label: could not convert string to float: '0.233398/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0096.jpg: ignoring corrupt image/label: could not convert string to float: '0.588185/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0097.jpg: ignoring corrupt image/label: could not convert string to float: '0.117676/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0098.jpg: ignoring corrupt image/label: could not convert string to float: '0.091596/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0099.jpg: ignoring corrupt image/label: could not convert string to float: '0.270736/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0100.jpg: ignoring corrupt image/label: could not convert string to float: '0.429688/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0101.jpg: ignoring corrupt image/label: could not convert string to float: '0.236198/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0102.jpg: ignoring corrupt image/label: could not convert string to float: '0.417692/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0103.jpg: ignoring corrupt image/label: could not convert string to float: '0.078125/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0104.jpg: ignoring corrupt image/label: could not convert string to float: '0.159245/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0105.jpg: ignoring corrupt image/label: could not convert string to float: '0.155524/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0106.jpg: ignoring corrupt image/label: could not convert string to float: '0.214066/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0107.jpg: ignoring corrupt image/label: could not convert string to float: '0.468262/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0108.jpg: ignoring corrupt image/label: could not convert string to float: '0.313587/n4'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0109.jpg: ignoring corrupt image/label: could not convert string to float: '0.136951/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0110.jpg: ignoring corrupt image/label: could not convert string to float: '0.182617/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0111.jpg: ignoring corrupt image/label: could not convert string to float: '0.134056/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0112.jpg: ignoring corrupt image/label: could not convert string to float: '0.303403/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0113.jpg: ignoring corrupt image/label: could not convert string to float: '0.052246/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0114.jpg: ignoring corrupt image/label: could not convert string to float: '0.199466/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0115.jpg: ignoring corrupt image/label: could not convert string to float: '0.223337/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0116.jpg: ignoring corrupt image/label: could not convert string to float: '0.101419/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0117.jpg: ignoring corrupt image/label: could not convert string to float: '0.232422/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0118.jpg: ignoring corrupt image/label: could not convert string to float: '0.320762/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0119.jpg: ignoring corrupt image/label: could not convert string to float: '0.324439/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0120.jpg: ignoring corrupt image/label: could not convert string to float: '0.080566/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0121.jpg: ignoring corrupt image/label: could not convert string to float: '0.195312/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0122.jpg: ignoring corrupt image/label: could not convert string to float: '0.073423/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0123.jpg: ignoring corrupt image/label: could not convert string to float: '0.074729/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0124.jpg: ignoring corrupt image/label: could not convert string to float: '0.229534/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0125.jpg: ignoring corrupt image/label: could not convert string to float: '0.060059/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0126.jpg: ignoring corrupt image/label: could not convert string to float: '0.217862/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0127.jpg: ignoring corrupt image/label: could not convert string to float: '0.439042/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0128.jpg: ignoring corrupt image/label: could not convert string to float: '0.531077/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0129.jpg: ignoring corrupt image/label: could not convert string to float: '0.481445/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0130.jpg: ignoring corrupt image/label: could not convert string to float: '0.090332/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0131.jpg: ignoring corrupt image/label: could not convert string to float: '0.204861/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0132.jpg: ignoring corrupt image/label: could not convert string to float: '0.113284/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0133.jpg: ignoring corrupt image/label: could not convert string to float: '0.159668/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0134.jpg: ignoring corrupt image/label: could not convert string to float: '0.512203/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0135.jpg: ignoring corrupt image/label: could not convert string to float: '0.197322/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0136.jpg: ignoring corrupt image/label: could not convert string to float: '0.077127/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0137.jpg: ignoring corrupt image/label: could not convert string to float: '0.169973/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0138.jpg: ignoring corrupt image/label: could not convert string to float: '0.067383/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0139.jpg: ignoring corrupt image/label: could not convert string to float: '0.289062/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0140.jpg: ignoring corrupt image/label: could not convert string to float: '0.320860/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0141.jpg: ignoring corrupt image/label: could not convert string to float: '0.327875/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0142.jpg: ignoring corrupt image/label: could not convert string to float: '0.069824/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0143.jpg: ignoring corrupt image/label: could not convert string to float: '0.080088/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0144.jpg: ignoring corrupt image/label: could not convert string to float: '0.379936/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0145.jpg: ignoring corrupt image/label: could not convert string to float: '0.213416/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0146.jpg: ignoring corrupt image/label: could not convert string to float: '0.182245/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0147.jpg: ignoring corrupt image/label: could not convert string to float: '0.169922/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0148.jpg: ignoring corrupt image/label: could not convert string to float: '0.170722/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0149.jpg: ignoring corrupt image/label: could not convert string to float: '0.200684/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0150.jpg: ignoring corrupt image/label: could not convert string to float: '0.181691/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0151.jpg: ignoring corrupt image/label: could not convert string to float: '0.463787/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0152.jpg: ignoring corrupt image/label: could not convert string to float: '0.440430/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0153.jpg: ignoring corrupt image/label: could not convert string to float: '0.303257/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0154.jpg: ignoring corrupt image/label: could not convert string to float: '0.085449/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0155.jpg: ignoring corrupt image/label: could not convert string to float: '0.082668/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0156.jpg: ignoring corrupt image/label: could not convert string to float: '0.180274/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0157.jpg: ignoring corrupt image/label: could not convert string to float: '0.104004/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0158.jpg: ignoring corrupt image/label: could not convert string to float: '0.147785/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0159.jpg: ignoring corrupt image/label: could not convert string to float: '0.251538/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0160.jpg: ignoring corrupt image/label: could not convert string to float: '0.052686/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0161.jpg: ignoring corrupt image/label: could not convert string to float: '0.081073/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0162.jpg: ignoring corrupt image/label: could not convert string to float: '0.167969/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0163.jpg: ignoring corrupt image/label: could not convert string to float: '0.138207/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0164.jpg: ignoring corrupt image/label: could not convert string to float: '0.052963/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0165.jpg: ignoring corrupt image/label: could not convert string to float: '0.255859/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0166.jpg: ignoring corrupt image/label: could not convert string to float: '0.542411/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0167.jpg: ignoring corrupt image/label: could not convert string to float: '0.479446/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0168.jpg: ignoring corrupt image/label: could not convert string to float: '0.470215/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0169.jpg: ignoring corrupt image/label: could not convert string to float: '0.225737/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0170.jpg: ignoring corrupt image/label: could not convert string to float: '0.223844/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0171.jpg: ignoring corrupt image/label: could not convert string to float: '0.128906/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0172.jpg: ignoring corrupt image/label: could not convert string to float: '0.429199/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0173.jpg: ignoring corrupt image/label: could not convert string to float: '0.371537/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0174.jpg: ignoring corrupt image/label: could not convert string to float: '0.402992/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0175.jpg: ignoring corrupt image/label: could not convert string to float: '0.333496/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0176.jpg: ignoring corrupt image/label: could not convert string to float: '0.356658/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0177.jpg: ignoring corrupt image/label: could not convert string to float: '0.341766/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0178.jpg: ignoring corrupt image/label: could not convert string to float: '0.270395/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0179.jpg: ignoring corrupt image/label: could not convert string to float: '0.070801/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0180.jpg: ignoring corrupt image/label: could not convert string to float: '0.282295/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0181.jpg: ignoring corrupt image/label: could not convert string to float: '0.362305/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0182.jpg: ignoring corrupt image/label: could not convert string to float: '0.304179/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0183.jpg: ignoring corrupt image/label: could not convert string to float: '0.140585/n'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0184.jpg: ignoring corrupt image/label: could not convert string to float: '0.235840/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0185.jpg: ignoring corrupt image/label: could not convert string to float: '0.249266/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0186.jpg: ignoring corrupt image/label: could not convert string to float: '0.282144/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0187.jpg: ignoring corrupt image/label: could not convert string to float: '0.160645/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0188.jpg: ignoring corrupt image/label: could not convert string to float: '0.038579/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0189.jpg: ignoring corrupt image/label: could not convert string to float: '0.161557/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0190.jpg: ignoring corrupt image/label: could not convert string to float: '0.352539/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0191.jpg: ignoring corrupt image/label: could not convert string to float: '0.205848/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0192.jpg: ignoring corrupt image/label: could not convert string to float: '0.133603/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0193.jpg: ignoring corrupt image/label: could not convert string to float: '0.417662/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0194.jpg: ignoring corrupt image/label: could not convert string to float: '0.122559/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0195.jpg: ignoring corrupt image/label: could not convert string to float: '0.097842/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0196.jpg: ignoring corrupt image/label: could not convert string to float: '0.064663/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0197.jpg: ignoring corrupt image/label: could not convert string to float: '0.137207/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0198.jpg: ignoring corrupt image/label: could not convert string to float: '0.149723/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0199.jpg: ignoring corrupt image/label: could not convert string to float: '0.271973/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0200.jpg: ignoring corrupt image/label: could not convert string to float: '0.394060/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0201.jpg: ignoring corrupt image/label: could not convert string to float: '0.276920/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0202.jpg: ignoring corrupt image/label: could not convert string to float: '0.120405/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0203.jpg: ignoring corrupt image/label: could not convert string to float: '0.338186/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0204.jpg: ignoring corrupt image/label: could not convert string to float: '0.367676/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0205.jpg: ignoring corrupt image/label: could not convert string to float: '0.057795/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0206.jpg: ignoring corrupt image/label: could not convert string to float: '0.046902/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0207.jpg: ignoring corrupt image/label: could not convert string to float: '0.110840/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0208.jpg: ignoring corrupt image/label: could not convert string to float: '0.278147/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0209.jpg: ignoring corrupt image/label: could not convert string to float: '0.189941/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0210.jpg: ignoring corrupt image/label: could not convert string to float: '0.231036/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0211.jpg: ignoring corrupt image/label: could not convert string to float: '0.150618/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0212.jpg: ignoring corrupt image/label: could not convert string to float: '0.082540/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0213.jpg: ignoring corrupt image/label: could not convert string to float: '0.157227/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0214.jpg: ignoring corrupt image/label: could not convert string to float: '0.180339/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0215.jpg: ignoring corrupt image/label: could not convert string to float: '0.180106/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0216.jpg: ignoring corrupt image/label: could not convert string to float: '0.233398/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0217.jpg: ignoring corrupt image/label: could not convert string to float: '0.409636/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0218.jpg: ignoring corrupt image/label: could not convert string to float: '0.351562/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0219.jpg: ignoring corrupt image/label: could not convert string to float: '0.409922/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0220.jpg: ignoring corrupt image/label: could not convert string to float: '0.126120/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0221.jpg: ignoring corrupt image/label: could not convert string to float: '0.271484/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0222.jpg: ignoring corrupt image/label: could not convert string to float: '0.192129/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0223.jpg: ignoring corrupt image/label: could not convert string to float: '0.163086/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0224.jpg: ignoring corrupt image/label: could not convert string to float: '0.355448/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0225.jpg: ignoring corrupt image/label: could not convert string to float: '0.111475/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0226.jpg: ignoring corrupt image/label: could not convert string to float: '0.069336/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0227.jpg: ignoring corrupt image/label: could not convert string to float: '0.162627/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0228.jpg: ignoring corrupt image/label: could not convert string to float: '0.158424/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0229.jpg: ignoring corrupt image/label: could not convert string to float: '0.157704/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0230.jpg: ignoring corrupt image/label: could not convert string to float: '0.078613/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0231.jpg: ignoring corrupt image/label: could not convert string to float: '0.080601/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0232.jpg: ignoring corrupt image/label: could not convert string to float: '0.462268/n1'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0233.jpg: ignoring corrupt image/label: could not convert string to float: '0.245424/n1'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0234.jpg: ignoring corrupt image/label: could not convert string to float: '0.454590/n1'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0235.jpg: ignoring corrupt image/label: could not convert string to float: '0.314949/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0236.jpg: ignoring corrupt image/label: could not convert string to float: '0.362864/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0237.jpg: ignoring corrupt image/label: could not convert string to float: '0.186035/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0238.jpg: ignoring corrupt image/label: could not convert string to float: '0.251735/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0239.jpg: ignoring corrupt image/label: could not convert string to float: '0.273438/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0240.jpg: ignoring corrupt image/label: could not convert string to float: '0.193203/n9'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0241.jpg: ignoring corrupt image/label: could not convert string to float: '0.105266/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0242.jpg: ignoring corrupt image/label: could not convert string to float: '0.387207/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0243.jpg: ignoring corrupt image/label: could not convert string to float: '0.092106/n3'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0244.jpg: ignoring corrupt image/label: could not convert string to float: '0.222168/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0245.jpg: ignoring corrupt image/label: could not convert string to float: '0.227108/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0246.jpg: ignoring corrupt image/label: could not convert string to float: '0.279567/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0247.jpg: ignoring corrupt image/label: could not convert string to float: '0.283992/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0248.jpg: ignoring corrupt image/label: could not convert string to float: '0.210470/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0249.jpg: ignoring corrupt image/label: could not convert string to float: '0.291016/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0250.jpg: ignoring corrupt image/label: could not convert string to float: '0.303430/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0251.jpg: ignoring corrupt image/label: could not convert string to float: '0.314794/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0252.jpg: ignoring corrupt image/label: could not convert string to float: '0.085449/n5'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0253.jpg: ignoring corrupt image/label: could not convert string to float: '0.250488/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0254.jpg: ignoring corrupt image/label: could not convert string to float: '0.327036/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0255.jpg: ignoring corrupt image/label: could not convert string to float: '0.277179/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0256.jpg: ignoring corrupt image/label: could not convert string to float: '0.116211/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0257.jpg: ignoring corrupt image/label: could not convert string to float: '0.168266/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0258.jpg: ignoring corrupt image/label: could not convert string to float: '0.148643/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0259.jpg: ignoring corrupt image/label: could not convert string to float: '0.162529/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0260.jpg: ignoring corrupt image/label: could not convert string to float: '0.123948/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0261.jpg: ignoring corrupt image/label: could not convert string to float: '0.207031/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0262.jpg: ignoring corrupt image/label: could not convert string to float: '0.274902/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0263.jpg: ignoring corrupt image/label: could not convert string to float: '0.680231/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0264.jpg: ignoring corrupt image/label: could not convert string to float: '0.674920/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0265.jpg: ignoring corrupt image/label: could not convert string to float: '0.176907/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0266.jpg: ignoring corrupt image/label: could not convert string to float: '0.325684/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0267.jpg: ignoring corrupt image/label: could not convert string to float: '0.136731/n8'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0268.jpg: ignoring corrupt image/label: could not convert string to float: '0.258325/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0269.jpg: ignoring corrupt image/label: could not convert string to float: '0.183040/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0270.jpg: ignoring corrupt image/label: could not convert string to float: '0.231934/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0271.jpg: ignoring corrupt image/label: could not convert string to float: '0.167625/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0272.jpg: ignoring corrupt image/label: could not convert string to float: '0.163859/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0273.jpg: ignoring corrupt image/label: could not convert string to float: '0.129395/n2'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0274.jpg: ignoring corrupt image/label: could not convert string to float: '0.204590/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0275.jpg: ignoring corrupt image/label: could not convert string to float: '0.273884/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0276.jpg: ignoring corrupt image/label: could not convert string to float: '0.339713/n0'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0277.jpg: ignoring corrupt image/label: could not convert string to float: '0.218425/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0278.jpg: ignoring corrupt image/label: could not convert string to float: '0.078125/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0279.jpg: ignoring corrupt image/label: could not convert string to float: '0.076171/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0280.jpg: ignoring corrupt image/label: could not convert string to float: '0.248434/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0281.jpg: ignoring corrupt image/label: could not convert string to float: '0.173828/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0282.jpg: ignoring corrupt image/label: could not convert string to float: '0.271552/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0283.jpg: ignoring corrupt image/label: could not convert string to float: '0.263296/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0284.jpg: ignoring corrupt image/label: could not convert string to float: '0.084346/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0285.jpg: ignoring corrupt image/label: could not convert string to float: '0.212891/n10'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0286.jpg: ignoring corrupt image/label: could not convert string to float: '0.234863/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0287.jpg: ignoring corrupt image/label: could not convert string to float: '0.533532/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0288.jpg: ignoring corrupt image/label: could not convert string to float: '0.515876/n6'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0289.jpg: ignoring corrupt image/label: could not convert string to float: '0.128592/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0290.jpg: ignoring corrupt image/label: could not convert string to float: '0.227044/n7'
# train: S:\hacatons\tools\Tools_yolov8-8\data\images\train\0291.jpg: ignoring corrupt image/label: could not convert string to float: '0.353027/n7'
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        497        560      0.938      0.866       0.93      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     169/200      3.21G     0.2947     0.2884     0.8948         45        640: 100% ━━━━━━━━━━━━ 218/218 10.0it/s 21.8s.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        497        560      0.933      0.871      0.931      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     170/200      3.21G     0.2938     0.2831     0.8938         48        640: 100% ━━━━━━━━━━━━ 218/218 9.9it/s 22.0s<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.2s
#                    all        497        560      0.942      0.862      0.931      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     171/200      3.21G     0.2884     0.2806     0.8917         61        640: 100% ━━━━━━━━━━━━ 218/218 9.7it/s 22.4s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.0it/s 2.2s0.2s
#                    all        497        560      0.942      0.865      0.931      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     172/200      3.21G     0.2944     0.2788     0.8957         67        640: 100% ━━━━━━━━━━━━ 218/218 10.0it/s 21.9s.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        497        560      0.944      0.867      0.932      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     173/200      3.21G     0.2947     0.2872     0.8965         39        640: 100% ━━━━━━━━━━━━ 218/218 10.0it/s 21.8s0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        497        560      0.944      0.867      0.932      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     174/200      3.21G     0.2898     0.2806     0.8906         34        640: 100% ━━━━━━━━━━━━ 218/218 9.6it/s 22.8s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.3s0.2s
#                    all        497        560      0.946      0.866      0.932      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     175/200      3.21G     0.2953     0.2871     0.8991         43        640: 100% ━━━━━━━━━━━━ 218/218 10.3it/s 21.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        497        560      0.952      0.861      0.933      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     176/200      3.21G     0.3003     0.2903     0.9008         58        640: 100% ━━━━━━━━━━━━ 218/218 9.7it/s 22.5s<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.0it/s 2.2s0.2s
#                    all        497        560      0.948      0.862      0.933      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     177/200      3.21G     0.2902     0.2801     0.8968         37        640: 100% ━━━━━━━━━━━━ 218/218 9.7it/s 22.4ss<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        497        560      0.962      0.847      0.933      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     178/200      3.21G     0.2973     0.2876      0.897         34        640: 100% ━━━━━━━━━━━━ 218/218 10.1it/s 21.6s.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.2s
#                    all        497        560      0.957      0.854      0.933      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     179/200      3.21G     0.2903     0.2796     0.8955         43        640: 100% ━━━━━━━━━━━━ 218/218 10.3it/s 21.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.2s
#                    all        497        560      0.956      0.854      0.933      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     180/200      3.21G     0.2842     0.2853     0.8915         36        640: 100% ━━━━━━━━━━━━ 218/218 10.2it/s 21.3s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        497        560      0.955      0.855      0.932      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     181/200      3.21G     0.2949     0.2887     0.8976         35        640: 100% ━━━━━━━━━━━━ 218/218 10.1it/s 21.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.0it/s 2.2s0.2s
#                    all        497        560      0.956      0.854      0.932       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     182/200      3.21G      0.291     0.2833     0.8936         42        640: 100% ━━━━━━━━━━━━ 218/218 10.1it/s 21.6s0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.2s
#                    all        497        560      0.956      0.855      0.932      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     183/200      3.21G     0.2949     0.2797     0.8973         43        640: 100% ━━━━━━━━━━━━ 218/218 9.7it/s 22.4s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.0it/s 2.2s0.2s
#                    all        497        560      0.956      0.855      0.932      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     184/200      3.21G     0.2936       0.28     0.8956         45        640: 100% ━━━━━━━━━━━━ 218/218 10.0it/s 21.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.0it/s 2.2s0.2s
#                    all        497        560      0.956      0.856      0.932       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     185/200      3.21G     0.2891     0.2794     0.8955         50        640: 100% ━━━━━━━━━━━━ 218/218 9.8it/s 22.2s<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        497        560      0.955      0.856      0.932      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     186/200      3.21G     0.2948     0.2846     0.9014         39        640: 100% ━━━━━━━━━━━━ 218/218 9.8it/s 22.3s0.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        497        560      0.954      0.857      0.931      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     187/200      3.21G     0.2895     0.2852     0.8958         36        640: 100% ━━━━━━━━━━━━ 218/218 9.9it/s 21.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        497        560      0.953      0.858       0.93      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     188/200      3.21G     0.2849     0.2771     0.8925         34        640: 100% ━━━━━━━━━━━━ 218/218 10.1it/s 21.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        497        560      0.954      0.856       0.93       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     189/200      3.21G      0.289     0.2764     0.8903         34        640: 100% ━━━━━━━━━━━━ 218/218 9.5it/s 22.9s<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        497        560       0.95      0.862       0.93      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     190/200      3.21G     0.2976     0.2869     0.9002         59        640: 100% ━━━━━━━━━━━━ 218/218 9.3it/s 23.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        497        560      0.954       0.86       0.93      0.889
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     191/200      3.21G     0.1988     0.1924     0.8215         20        640: 100% ━━━━━━━━━━━━ 218/218 9.0it/s 24.3s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        497        560      0.954      0.858       0.93       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     192/200      3.21G     0.1946     0.1886     0.8215         19        640: 100% ━━━━━━━━━━━━ 218/218 9.5it/s 22.9s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.3s0.2s
#                    all        497        560      0.966      0.842       0.93      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     193/200      3.21G     0.1952     0.1916     0.8237         20        640: 100% ━━━━━━━━━━━━ 218/218 9.5it/s 23.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        497        560      0.966      0.842       0.93      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     194/200      3.21G     0.1928     0.1878     0.8227         20        640: 100% ━━━━━━━━━━━━ 218/218 9.5it/s 23.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        497        560      0.965      0.842      0.931       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/200      3.21G     0.1897     0.1831     0.8236         20        640: 100% ━━━━━━━━━━━━ 218/218 9.4it/s 23.3s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        497        560      0.942      0.861      0.931      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/200      3.21G     0.1893      0.184     0.8195         20        640: 100% ━━━━━━━━━━━━ 218/218 9.4it/s 23.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.3s0.2s
#                    all        497        560      0.941      0.861      0.931      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/200      3.21G     0.1906      0.186      0.826         20        640: 100% ━━━━━━━━━━━━ 218/218 9.4it/s 23.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        497        560       0.94      0.861      0.931      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/200      3.21G     0.1884     0.1839     0.8219         19        640: 100% ━━━━━━━━━━━━ 218/218 9.4it/s 23.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        497        560      0.952      0.853      0.931       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/200      3.21G     0.1886     0.1807     0.8192         20        640: 100% ━━━━━━━━━━━━ 218/218 9.5it/s 23.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        497        560       0.95      0.857      0.931       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     200/200      3.21G     0.1887     0.1837     0.8186         20        640: 100% ━━━━━━━━━━━━ 218/218 9.5it/s 23.0s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        497        560      0.945      0.859      0.931      0.889
#
# 200 epochs completed in 1.343 hours.
# Optimizer stripped from S:\hacatons\tools\Tools_yolov8-8\runs\detect\train26\weights\last.pt, 6.3MB
# Optimizer stripped from S:\hacatons\tools\Tools_yolov8-8\runs\detect\train26\weights\best.pt, 6.3MB
#
# Validating S:\hacatons\tools\Tools_yolov8-8\runs\detect\train26\weights\best.pt...
# Ultralytics 8.3.203  Python-3.12.6 torch-2.10.0.dev20250926+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 3,007,793 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.5it/s 2.9s0.2s
#                    all        497        560      0.969       0.84      0.931      0.891
#      Adjustable_wrench         62         62      0.946      0.842      0.912      0.858
#          screwdriver_1         29         29      0.923      0.793      0.896      0.846
#          screwdriver_2         35         35          1      0.815      0.917      0.881
# Offset_Phillips_screwdriver         31         31      0.978      0.806      0.854      0.831
#           Side_cutters         31         31      0.894      0.903      0.978      0.942
#               Shernica         68         68          1      0.905      0.981      0.945
#          Safety_pliers         86         86      0.988      0.943      0.989      0.957
#                 Pliers         36         36      0.988      0.889      0.968      0.917
#           Rotary_wheel         94         97      0.943      0.629      0.783      0.732
#        Open_end_wrench         46         46          1      0.829      0.984      0.933
#         Oil_can_opener         39         39          1      0.889      0.984      0.958
# Speed: 0.2ms preprocess, 1.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to S:\hacatons\tools\Tools_yolov8-8\runs\detect\train26
